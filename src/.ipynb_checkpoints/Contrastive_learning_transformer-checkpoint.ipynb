# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
from sklearn.model_selection import train_test_split
import tensorflow as tf
import tensorflow.math as tfmath
import tensorflow.keras as keras
from tensorflow.keras import layers, Model
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import load_model
from sklearn.metrics import roc_curve, auc
import sklearn.metrics as sk

import os
import glob

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Concatenate, Dense, Conv2D, LeakyReLU, ReLU, Dropout, BatchNormalization, Activation
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.metrics import Precision
from tensorflow.keras.regularizers import l1_l2
# Out:
# 2025-07-14 04:10:48.506991: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-14 04:10:48.507023: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-14 04:10:48.508174: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-14 04:10:48.514632: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-14 04:10:50.833966: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# %pip install plotly

# %%
import plotly
from sklearn.metrics import roc_curve, auc
from tqdm import trange
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:                   # enable on all GPUs
        tf.config.experimental.set_memory_growth(gpu, True)
    # OR keep only one GPU visible instead of touching memory-growth:
    # tf.config.set_visible_devices(gpus[0], 'GPU')
else:
    raise RuntimeError("No GPU detected")

# %%
with h5py.File('../data/processed_data/background_for_training_dataset.h5', 'r') as hf:
    X_train = hf['X_train'][:]
    X_test = hf['X_test'][:]
    X_val = hf['X_val'][:]
    X_discovery = hf['X_discovery'][:]

# Load signal data
with h5py.File('../data/processed_data/Ato4l_lepFilter_13TeV_filtered_dataset.h5', 'r') as hf:
    Ato4l_data = hf['Data'][:]

with h5py.File('../data/processed_data/hToTauTau_13TeV_PU20_filtered_dataset.h5', 'r') as hf:
    hToTauTau_data = hf['Data'][:]

with h5py.File('../data/processed_data/hChToTauNu_13TeV_PU20_filtered_dataset.h5', 'r') as hf:
    hChToTauNu_data = hf['Data'][:]

with h5py.File('../data/processed_data/leptoquark_LOWMASS_lepFilter_13TeV_filtered_dataset.h5', 'r') as hf:
    leptoquark_data = hf['Data'][:]

print("Data loaded from processed datasets")
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"X_val shape: {X_val.shape}")
print(f"X_discovery shape: {X_discovery.shape}")
print(f"Ato4l_data shape: {Ato4l_data.shape}")
print(f"hToTauTau_data shape: {hToTauTau_data.shape}")
print(f"hChToTauNu_data shape: {hChToTauNu_data.shape}")
print(f"leptoquark_data shape: {leptoquark_data.shape}")
# Out:
# Data loaded from processed datasets
# X_train shape: (7748303, 57)
# X_test shape: (2421345, 57)
# X_val shape: (1937076, 57)
# X_discovery shape: (1345191, 57)
# Ato4l_data shape: (55969, 57)
# hToTauTau_data shape: (691283, 57)
# hChToTauNu_data shape: (760272, 57)
# leptoquark_data shape: (340544, 57)

# %%
# from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
# import pickle

# # Fit StandardScaler on background training data
# scaler = MinMaxScaler().fit(X_train)
# X_train_scaled = scaler.transform(X_train)
# X_val_scaled = scaler.transform(X_val)
# X_test_scaled = scaler.transform(X_test)
# X_discovery_scaled = scaler.transform(X_discovery)

# # Transform signal data
# Ato4l_data_scaled = scaler.transform(Ato4l_data)
# hToTauTau_data_scaled = scaler.transform(hToTauTau_data)
# hChToTauNu_data_scaled = scaler.transform(hChToTauNu_data)
# leptoquark_data_scaled = scaler.transform(leptoquark_data)

# # Save scaler for later use
# with open('../models/scaler.pkl', 'wb') as f:
#     pickle.dump(scaler, f)
from sklearn.preprocessing import StandardScaler
import pickle

# select columns whose 1-based index is a multiple of 3
cols = [i for i in range(X_train.shape[1]) if i % 3 == 0]

# fit scaler on those columns in the background training sample
scaler = StandardScaler().fit(X_train[:, cols])

# helper to apply scaling only to selected columns
def scale(X):
    Xs = X.copy()
    Xs[:, cols] = scaler.transform(X[:, cols])
    return Xs

# apply to all datasets
X_train_scaled      = scale(X_train)
X_val_scaled        = scale(X_val)
X_test_scaled       = scale(X_test)
X_discovery_scaled  = scale(X_discovery)

# signal samples
Ato4l_data_scaled       = scale(Ato4l_data)
hToTauTau_data_scaled   = scale(hToTauTau_data)
hChToTauNu_data_scaled  = scale(hChToTauNu_data)
leptoquark_data_scaled  = scale(leptoquark_data)

# persist scaler
with open('../models/scaler_euclid.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %%
# η are at indices 1,4,7,… (i % 3 == 1)
eta_vals = X_train_scaled[:, 1::3].ravel()
# φ are at indices 2,5,8,… (i % 3 == 2)
phi_vals = X_train_scaled[:, 2::3].ravel()

print("η range:", eta_vals.min(), "to", eta_vals.max())
print("φ range:", phi_vals.min(), "to", phi_vals.max())
# Out:
# η range: -3.9999990463256836 to 3.9999947547912598
# φ range: -3.141591787338257 to 3.141592502593994

# %%
pt_vals = X_train_scaled[:, 0::3].ravel()
print("pt range:", pt_vals.min(), "to", pt_vals.max())
plt.hist(pt_vals)
plt.show()
# Out:
# pt range: -1.7082650502429007 to 709.2991468349312

# %%
zero_evt = np.zeros((1, X_train.shape[1]))

# apply your scale() helper
zero_scaled = scale(zero_evt)

# that’s your transformed vector:
print(zero_scaled)

# for a quick check, the non-zero entries should be at `cols` and equal to -(mean_/scale_)  
manual = np.zeros_like(zero_evt)
manual[:, cols] = -scaler.mean_ / scaler.scale_
print("matches:", np.allclose(zero_scaled, manual))
# Out:
# [[-1.7087929   0.          0.         -0.94244273  0.          0.
#   -0.17153238  0.          0.         -0.02456616  0.          0.
#   -0.0052941   0.          0.         -0.83618826  0.          0.
#   -0.15430631  0.          0.         -0.02040254  0.          0.
#   -0.00332566  0.          0.         -0.80906082  0.          0.
#   -0.51457733  0.          0.         -0.3390071   0.          0.
#   -0.2080887   0.          0.         -0.12343861  0.          0.
#   -0.07135473  0.          0.         -0.04083839  0.          0.
#   -0.02272765  0.          0.         -0.01267088  0.          0.
#   -0.00701831  0.          0.        ]]
# matches: True

# %%
c_vals = (-scaler.mean_ / scaler.scale_).astype(np.float32)
empty_trip = np.zeros((19, 3), dtype=np.float32)
empty_trip[:, 0] = c_vals

# %%
# Use scaled data for training
signal_dict = {
    'hToTauTau': hToTauTau_data_scaled,
    'Ato4l': Ato4l_data_scaled,
    'hChToTauNu': hChToTauNu_data_scaled,
    'leptoquark': leptoquark_data_scaled
}

# %%
np.isnan(X_val_scaled).any()
# Out:
# False

# %%
from tensorflow.keras import regularizers, initializers

class SignalSamplingSequence(keras.utils.Sequence):
    """Custom data generator for VAE training with signal sampling"""
    
    def __init__(self, X_background, signal_data_dict, batch_size=32, n_signal_samples=1000):
        """
        Args:
            X_background: Background training data
            signal_data_dict: Dictionary of signal data {signal_name: data}
            batch_size: Batch size for background
            n_signal_samples: Number of samples to take from each signal
        """
        self.X_background = X_background
        self.signal_data_dict = signal_data_dict
        self.batch_size = batch_size
        self.n_signal_samples = n_signal_samples
        self.n_batches = len(X_background) // batch_size
    
    def sample_signals(self):
        """Randomly sample signals for current batch"""
        sampled_signals = {}
        for signal_name, signal_data in self.signal_data_dict.items():
            if signal_name != 'BSMchannel':
                n_available = len(signal_data)
                n_to_sample = min(self.n_signal_samples, n_available)
                indices = np.random.choice(n_available, n_to_sample, replace=False)
                sampled_signals[signal_name] = signal_data[indices]
        return sampled_signals
    
    def __len__(self):
        return self.n_batches
    
    def __getitem__(self, idx):
        # Get background batch
        start_idx = idx * self.batch_size
        end_idx = start_idx + self.batch_size
        background_batch = self.X_background[start_idx:end_idx]
        
        # Sample signals for this batch
        sampled_signals = self.sample_signals()
        
        # Return background and sampled signals
        return (background_batch, sampled_signals)
    
    def on_epoch_end(self):
        """Called at the end of each epoch"""
        # Shuffle background data if needed
        pass


# --------------------------------------------------------------
# helper: cyclic β and linear-warmup γ
# --------------------------------------------------------------
# def cyclic_beta(global_step, steps_per_epoch, cycle_len, bmin, bmax):
#     epoch = tf.cast(global_step, tf.float32) / tf.cast(steps_per_epoch, tf.float32)
#     c = tf.floor(1. + epoch / cycle_len)
#     x = tf.abs(epoch / cycle_len - c + 1.)
#     return bmin + (bmax - bmin) * tf.minimum(x, 1.)
def cyclic_beta(global_step, steps_per_epoch, cycle_len, bmin, bmax):
    # convert global step to fractional epochs
    epoch = tf.cast(global_step, tf.float32) / tf.cast(steps_per_epoch, tf.float32)
    # position within the current cycle [0, cycle_len)
    cycle_pos = tf.math.floormod(epoch, cycle_len)
    # normalized position [0,1)
    frac = cycle_pos / cycle_len

    # ramp up over first half, hold at 1 over second half
    ramp_frac = frac * 2.0
    scaled = tf.where(frac < 0.5,
                      ramp_frac,
                      tf.ones_like(frac))

    # map [0,1] → [bmin,bmax]
    return bmin + (bmax - bmin) * scaled
def warm_gamma(global_step, steps_per_epoch, warm_epochs, gmax):
    # epoch counter (float)
    e = tf.cast(global_step, tf.float32) / tf.cast(steps_per_epoch, tf.float32)
    # 0 for e < warm_epochs
    # linear ramp to 1 for warm_epochs ≤ e < 2*warm_epochs
    # 1 for e ≥ 2*warm_epochs
    return gmax * tf.clip_by_value((e - warm_epochs) / warm_epochs, 0., 1.)

def _scale(v):
    return v / tf.cast(tf.distribute.get_strategy().num_replicas_in_sync, tf.float32)

# %%
L2   = 1e-3          # weight-decay factor
DROPOUT = 0.1        # after each hidden layer
# --------------------------------------------------------------
# main model
# --------------------------------------------------------------
class VAEContrastive(keras.Model):
    def __init__(
        self,
        input_dim,                      # must == seq_len * feat_dim
        latent_dim,
        *,
        steps_per_epoch,
        cycle_length=10,
        beta_min=0.1, beta_max=0.85,
        warmup_epochs=5,
        gamma_max=1.0,
        # ─ transformer hyper-params ─
        seq_len=19, feat_dim=3,
        model_dim=128, n_heads=4,
        n_layers=4,  ff_dim=256,
        **kw,
    ):
        super().__init__(**kw)
        assert input_dim == seq_len * feat_dim
        self.steps_per_epoch = tf.constant(steps_per_epoch, tf.int32)
        self.cycle_len, self.bmin, self.bmax = float(cycle_length), float(beta_min), float(beta_max)
        self.warm_epochs, self.gmax = float(warmup_epochs), float(gamma_max)
        self.empty_trip = tf.constant(empty_trip, dtype=tf.float32)

        # ─ encoder : transformer ─
        enc_in = keras.Input(shape=(input_dim,))
        x = layers.Reshape((seq_len, feat_dim))(enc_in)          # flat → tokens
        x = layers.Dense(model_dim)(x)                           # token projection

        pos = tf.range(seq_len)
        pos_emb = layers.Embedding(seq_len, model_dim)(pos)      # learned positional enc.
        x = x + pos_emb

        for _ in range(n_layers):
            attn = layers.MultiHeadAttention(n_heads, key_dim=model_dim)(x, x)
            x = layers.LayerNormalization(epsilon=1e-6)(x + attn)
            ffn = layers.Dense(ff_dim, activation='gelu')(x)
            ffn = layers.Dense(model_dim)(ffn)
            x = layers.LayerNormalization(epsilon=1e-6)(x + ffn)

        x = layers.GlobalAveragePooling1D()(x)
        z_mean = layers.Dense(latent_dim)(x)
        z_logv = layers.Dense(latent_dim, bias_initializer=initializers.Constant(-2.0))(x)
        z_logv = tf.clip_by_value(z_logv, -10., 10.)
        z = layers.Lambda(lambda t: t[0] + tf.exp(0.5*t[1]) * tf.random.normal(tf.shape(t[0])))([z_mean, z_logv])
        self.encoder = keras.Model(enc_in, [z_mean, z_logv, z], name="encoder")

        # ─ decoder : transformer ─
        dec_in = keras.Input(shape=(latent_dim,))
        y = layers.Dense(seq_len * model_dim)(dec_in)
        y = layers.Reshape((seq_len, model_dim))(y)

        for _ in range(n_layers):
            attn = layers.MultiHeadAttention(n_heads, key_dim=model_dim)(y, y)
            y = layers.LayerNormalization(epsilon=1e-6)(y + attn)
            ffn = layers.Dense(ff_dim, activation='gelu')(y)
            ffn = layers.Dense(model_dim)(ffn)
            y = layers.LayerNormalization(epsilon=1e-6)(y + ffn)

        y = layers.Dense(feat_dim)(y)                            # back to (seq_len,feat_dim)
        raw = layers.Reshape((input_dim,))(y)

        # ─ same η/φ constraints as before ─
        x3   = layers.Reshape((seq_len, feat_dim))(raw)
        other, eta_raw, phi_raw = x3[..., :1], x3[...,1:2], x3[...,2:3]
        eta  = layers.Lambda(lambda t: 4.0 * tf.tanh(t))(eta_raw)          # [-4,4]
        phi  = layers.Lambda(lambda t: np.pi * tf.tanh(t))(phi_raw)        # [-π,π]
        out3 = layers.Concatenate(-1)([other, eta, phi])
        dec_out = layers.Reshape((input_dim,))(out3)

        self.decoder = keras.Model(dec_in, dec_out, name="decoder")

        # ─ trackers unchanged ─
        self.total_loss_tracker = keras.metrics.Mean("total")
        self.recon_tracker      = keras.metrics.Mean("recon")
        self.kl_tracker         = keras.metrics.Mean("kl")
        self.contrast_tracker   = keras.metrics.Mean("contrast")
        self.beta_tracker       = keras.metrics.Mean("beta")
        self.gamma_tracker      = keras.metrics.Mean("gamma")

        self.global_step = tf.Variable(0, trainable=False, dtype=tf.int32)

    @property
    def metrics(self):
        return [ self.total_loss_tracker, self.recon_tracker,
                 self.kl_tracker, self.contrast_tracker,
                 self.beta_tracker, self.gamma_tracker ]

    # ─ contrastive loss (InfoNCE style, averaged) ─
    def contrastive(self, signal_latents_dict, k=100):
        """
        Info-NCE over *signals only*.
        Positives = same-signal pairs (excluding self);
        Negatives = all other signal samples.
        """
        if not signal_latents_dict:
            return tf.constant(0.0, tf.float32)

        # ─ concatenate latents and build class labels ─
        all_latents, labels = [], []
        for idx, (name, z_sig) in enumerate(signal_latents_dict.items()):
            all_latents.append(z_sig)
            labels.append(tf.fill([tf.shape(z_sig)[0]], idx))
        z_sig  = tf.concat(all_latents, 0)          # [n_sig , d]
        labels = tf.concat(labels,     0)           # [n_sig]

        # # ─ similarity matrix (euclid) ─
        # tau  = 0.05
        # sq   = tf.reduce_sum(tf.square(z_sig), axis=1, keepdims=True)          # ‖z_i‖²
        # dist = sq - 2.0 * tf.matmul(z_sig, z_sig, transpose_b=True) + tf.transpose(sq)  # ‖Δ‖²
        # sim  = tf.exp(-dist / tau)

        # ─ similarity matrix (exp(cos)) ─
        nz  = tf.nn.l2_normalize(z_sig, 1)
        sim = tf.exp(tf.matmul(nz, nz, transpose_b=True)/0.05)   # [N , N]

        n_sig = tf.shape(z_sig)[0]
        eye   = tf.eye(n_sig, dtype=tf.float32)
        sim_no_self = sim * (1.0 - eye)              # remove self-similarity

        # positive mask: same class, not self
        lab = tf.expand_dims(labels, 1)
        pos_mask = tf.cast(tf.equal(lab, tf.transpose(lab)), tf.float32) * (1.0 - eye)

        # A(x) = sum_{pos} sim
        A = tf.reduce_sum(sim * pos_mask, 1)
        # B(x) = sum_{all≠x} sim
        B = tf.reduce_sum(sim_no_self, 1)

        A = tf.maximum(A, 1e-6);  B = tf.maximum(B, 1e-6)
        return -tf.reduce_mean(tf.math.log(A / B))
    
    def masked_mse(self, x, recon):
        # reshape into (B, num_objs, 3)
        x3 = tf.reshape(x, [-1, 19, 3])

        # compare to empty_trip within tolerance
        eq0 = tf.abs(x3 - self.empty_trip[None, ...]) < 1e-6
        empty_mask = tf.reduce_all(eq0, axis=-1)             # (B, num_objs)

        # expand to (B,57)
        mask3 = tf.reshape(
            tf.repeat(empty_mask[..., None], repeats=3, axis=-1),
            [-1, input_dim]
        )
        keep = 1.0 - tf.cast(mask3, tf.float32)

        # masked MSE
        sq = tf.square(x - recon)
        return tf.reduce_sum(sq * keep) / tf.reduce_sum(keep)


    def contrastive_hard(self, signal_latents_dict, k=100):
        """
        Hard-mined InfoNCE.
        • Numerator  A = Σ (k farthest positives)      – lowest cosine-sim entries
        • Denominator B = Σ (k closest  negatives)     – highest cosine-sim entries
        Assumes every anchor has ≥ k positives and ≥ k negatives.
        """
        if not signal_latents_dict:
            return tf.constant(0.0, tf.float32)

        # ─ concat latents & labels ─
        z_list, lbl_list = [], []
        for cls_id, (_, z) in enumerate(signal_latents_dict.items()):
            z_list.append(z)
            lbl_list.append(tf.fill([tf.shape(z)[0]], cls_id))
        z_sig  = tf.concat(z_list, 0)       # [N , d]
        labels = tf.concat(lbl_list, 0)     # [N]

        # ─ similarity matrix (exp(cos)) ─
        nz  = tf.nn.l2_normalize(z_sig, 1)
        sim = tf.exp(tf.matmul(nz, nz, transpose_b=True)/0.05)   # [N , N]

        N   = tf.shape(z_sig)[0]
        eye = tf.eye(N, dtype=tf.float32)

        lab = tf.expand_dims(labels, 1)
        pos_mask = tf.cast(tf.equal(lab, tf.transpose(lab)), tf.float32) * (1.0 - eye)
        neg_mask = (1.0 - eye) - pos_mask

        # farthest positives: smallest sims
        pos_sims = tf.where(pos_mask > 0,
                            sim,
                            tf.fill(tf.shape(sim), tf.float32.max))
        hardest_pos = -tf.nn.top_k(-pos_sims, k=k, sorted=False).values   # [N , k]

        # closest negatives: largest sims
        neg_sims = tf.where(neg_mask > 0,
                            sim,
                            tf.fill(tf.shape(sim), tf.float32.min))
        hardest_neg = tf.nn.top_k(neg_sims, k=k, sorted=False).values     # [N , k]

        A = tf.reduce_sum(hardest_pos, axis=1)        # numerator
        B = tf.reduce_sum(hardest_neg, axis=1)        # denominator

        eps = 1e-6
        return -tf.reduce_mean(tf.math.log(tf.maximum(A, eps) / (tf.maximum(B, eps) + tf.maximum(A, eps))))
 
    # ─ training step ─
    def train_step(self, data):
        bg, sig = data if isinstance(data, tuple) else (data, {})
        β = cyclic_beta(self.global_step, self.steps_per_epoch, self.cycle_len, self.bmin, self.bmax)
        γ = warm_gamma(self.global_step, self.steps_per_epoch, self.warm_epochs, self.gmax)

        with tf.GradientTape(persistent=True) as tape:
            μ, logv, z_bg = self.encoder(bg)
            recon = self.decoder(z_bg)

            recon_loss = self.masked_mse(bg, recon)
            kl = tf.reduce_mean(-0.5 * (1 + logv - tf.exp(logv)))
            sig_lat = {k: self.encoder(v)[-1] for k, v in sig.items() if k != "BSMchannel"}
            #contrast = self.contrastive_hard(sig_lat, k=500)
            contrast = self.contrastive(sig_lat)

            loss = (1-β) * recon_loss + β * kl + γ * contrast        
            
            
        vars_ = self.trainable_weights
        g_recon    = tape.gradient(recon_loss, vars_)
        g_kl       = tape.gradient(kl,         vars_)
        g_contrast = tape.gradient(contrast,   vars_)
        g_total    = tape.gradient(loss,       vars_)
        del tape

        # pad Nones with zeros so all vectors share |θ| dimensions
        def flat(glist):
            return tf.concat(
                [tf.reshape(g if g is not None else tf.zeros_like(v), [-1])
                for g, v in zip(glist, vars_)],
                axis=0)

        v_recon, v_kl, v_contrast = map(flat, (g_recon, g_kl, g_contrast))

        # cosine similarities (<0 ⇒ conflict)
        sim_kl_recon  = tf.tensordot(v_kl, v_recon, 1) / (tf.norm(v_kl)*tf.norm(v_recon)+1e-9)
        sim_con_recon = tf.tensordot(v_contrast, v_recon, 1) / (tf.norm(v_contrast)*tf.norm(v_recon)+1e-9)
        sim_con_kl    = tf.tensordot(v_contrast, v_kl, 1) / (tf.norm(v_contrast)*tf.norm(v_kl)+1e-9)

        self.optimizer.apply_gradients(zip(g_total, vars_))
        self.global_step.assign_add(1)

        self.total_loss_tracker.update_state(loss)
        self.recon_tracker.update_state(recon_loss)
        self.kl_tracker.update_state(kl)
        self.contrast_tracker.update_state(contrast)
        self.beta_tracker.update_state(β)
        self.gamma_tracker.update_state(γ)

        return {"loss": self.total_loss_tracker.result(),
                "recon": self.recon_tracker.result(),
                "kl":    self.kl_tracker.result(),
                "contrast": self.contrast_tracker.result(),
                "beta": self.beta_tracker.result(),
                "gamma": self.gamma_tracker.result(),
                "sim_kl_recon": sim_kl_recon,
                "sim_con_recon": sim_con_recon,
                "sim_con_kl": sim_con_kl}

    # ─ inference ─
    def call(self, x):
        μ, logv, z = self.encoder(x)
        return {"z_mean": μ, "z_log_var": logv, "reconstruction": self.decoder(z)}
    def test_step(self, data):
        bg, sig = data if isinstance(data, tuple) else (data, {})

        beta   = self.bmax            # use max values
        gamma  = self.gmax

        # forward pass
        μ, logv, z_bg = self.encoder(bg, training=False)
        recon         = self.decoder(z_bg, training=False)

        # losses
        recon_loss = self.masked_mse(bg, recon)

        kl = -0.5 * (1. + logv - tf.exp(logv))
        kl = tf.reduce_mean(kl)

        sig_lat = {k: self.encoder(v, training=False)[-1]
                   for k, v in sig.items() if k != "BSMchannel"}
        contrast = self.contrastive(sig_lat)

        loss = (1. - beta) * recon_loss + beta * kl + gamma * contrast
        
        # update trackers
        self.total_loss_tracker.update_state(loss)
        self.recon_tracker.update_state(recon_loss)
        self.kl_tracker.update_state(kl)
        self.contrast_tracker.update_state(contrast)
        self.beta_tracker.update_state(beta)
        self.gamma_tracker.update_state(gamma)

        return {m.name: m.result() for m in self.metrics}

# %%
# Import the VAE model and data generator from the previous file
# from vae_contrastive_model import VAEWithContrastive, SignalSamplingSequence, EpochCounterCallback

# Load data
print("Loading data...")

# Model parameters
input_dim = X_train.shape[1]
latent_dim = 8
batch_size = 4096*4

# Training parameters
epochs = 50
warmup_epochs = 10
beta_min = 0.0
beta_max = 0.25
cycle_length = 10
gamma = 2
learning_rate = 1e-3

steps_per_epoch = len(X_train_scaled) // batch_size
lr_warmup_epochs = 10 
lr_steps_warmup  = steps_per_epoch * lr_warmup_epochs
lr_steps_cosine  = steps_per_epoch * (epochs - lr_warmup_epochs)
lr_warmup = keras.optimizers.schedules.PolynomialDecay(
    initial_learning_rate=1e-5,
    end_learning_rate=1e-4,
    decay_steps=lr_steps_warmup,
    power=1.0)

lr_cosine = keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=1e-4,
    decay_steps=lr_steps_cosine,
    alpha=0.1)      

class WarmupCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, warmup, cosine, transition):
        super().__init__()
        self.warmup      = warmup
        self.cosine      = cosine
        self.transition  = tf.constant(transition, dtype=tf.int64)

    def __call__(self, step):
        step = tf.cast(step, tf.int64)
        return tf.cond(step < self.transition,
                       lambda: self.warmup(step),
                       lambda: self.cosine(step - self.transition))

    def get_config(self):   # makes the schedule serialisable
        return {
            "warmup":      keras.saving.serialize_keras_object(self.warmup),
            "cosine":      keras.saving.serialize_keras_object(self.cosine),
            "transition":  int(self.transition.numpy()),
        }

lr_schedule = WarmupCosine(lr_warmup, lr_cosine, lr_steps_warmup)

# Create model
print("\nCreating VAE model...")
strategy = tf.distribute.MirroredStrategy()
with strategy.scope():
    vae = VAEContrastive(
        input_dim=input_dim,
        latent_dim=latent_dim,
        steps_per_epoch=steps_per_epoch,   # always first of the sched-params
        cycle_length=cycle_length,         # β cycle
        beta_min=beta_min,
        beta_max=beta_max,
        warmup_epochs=warmup_epochs,       # γ warm-up
        gamma_max=gamma,
        seq_len=19, feat_dim=3,
        model_dim=256, n_heads=2,
        n_layers=2, ff_dim=512               
    )
    vae.compile(optimizer=keras.optimizers.AdamW(lr_schedule, clipnorm=0.5, weight_decay=1e-4))

# Update train generator with scaled data
train_generator = SignalSamplingSequence(
    X_train_scaled, 
    signal_dict,
    batch_size=batch_size,
    n_signal_samples=1000
)

val_generator = SignalSamplingSequence(
    X_val_scaled,
    signal_dict,
    batch_size=batch_size,
    n_signal_samples=1000)

# Train model
print("\nStarting training...")
history = vae.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator,
    verbose=1
)

# Save the trained model
print("\nSaving model...")
vae.encoder.save('../models/vae_encoder_10epochs_transformer.h5')
vae.decoder.save('../models/vae_decoder_10epochs_transformer.h5')
# Out:
# Loading data...
#
# Creating VAE model...
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# 2025-07-14 04:11:20.245319: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38366 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:03:00.0, compute capability: 8.0
# 2025-07-14 04:11:20.247934: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 38366 MB memory:  -> device: 1, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:41:00.0, compute capability: 8.0
# 2025-07-14 04:11:20.249810: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 38366 MB memory:  -> device: 2, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:82:00.0, compute capability: 8.0
# 2025-07-14 04:11:20.253414: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 38366 MB memory:  -> device: 3, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:c1:00.0, compute capability: 8.0
# Starting training...
# WARNING:tensorflow:Using MirroredStrategy eagerly has significant overhead currently. We will be working on improving this in the future, but for now please wrap `call_for_each_replica` or `experimental_run` or `run` inside a tf.function to get the best performance.
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 74 all_reduces, num_devices = 4, group_size = 4, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Collective all_reduce tensors: 74 all_reduces, num_devices = 4, group_size = 4, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 2025-07-14 04:12:34.736478: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f9b94408b30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-07-14 04:12:34.736511: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A100-SXM4-40GB, Compute Capability 8.0
# 2025-07-14 04:12:34.736524: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA A100-SXM4-40GB, Compute Capability 8.0
# 2025-07-14 04:12:34.736529: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (2): NVIDIA A100-SXM4-40GB, Compute Capability 8.0
# 2025-07-14 04:12:34.736533: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (3): NVIDIA A100-SXM4-40GB, Compute Capability 8.0
# 2025-07-14 04:12:34.747010: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-07-14 04:12:34.820790: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8903
# 2025-07-14 04:12:34.822726: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8903
# 2025-07-14 04:12:34.825234: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8903
# 2025-07-14 04:12:34.828045: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8903
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752491554.919780 1342863 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 472/472 [==============================] - 304s 492ms/step - loss: 2.9049 - recon: 1.9830 - kl: 1.7261 - contrast: 1.3105 - beta: 0.0249 - gamma: 0.0000e+00 - sim_kl_recon: -0.4579 - sim_con_recon: -0.0180 - sim_con_kl: 0.4211 - val_total: 4.1497 - val_recon: 1.3185 - val_kl: 2.2335 - val_contrast: 1.3012 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 2/50
# 472/472 [==============================] - 226s 479ms/step - loss: 1.2668 - recon: 1.1585 - kl: 1.8555 - contrast: 1.2872 - beta: 0.0749 - gamma: 0.0000e+00 - sim_kl_recon: -0.3079 - sim_con_recon: 0.0275 - sim_con_kl: -0.0957 - val_total: 3.6147 - val_recon: 1.0535 - val_kl: 1.1512 - val_contrast: 1.2683 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 3/50
# 472/472 [==============================] - 226s 479ms/step - loss: 0.9957 - recon: 0.9925 - kl: 0.5718 - contrast: 1.2442 - beta: 0.1249 - gamma: 0.0000e+00 - sim_kl_recon: -0.7908 - sim_con_recon: 0.2707 - sim_con_kl: -0.9207 - val_total: 3.2193 - val_recon: 0.9620 - val_kl: 0.2126 - val_contrast: 1.2223 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 4/50
# 472/472 [==============================] - 226s 478ms/step - loss: 0.7712 - recon: 0.8862 - kl: 0.1174 - contrast: 1.2052 - beta: 0.1749 - gamma: 0.0000e+00 - sim_kl_recon: -0.6093 - sim_con_recon: 0.2784 - sim_con_kl: -0.4811 - val_total: 3.0479 - val_recon: 0.8433 - val_kl: 0.0642 - val_contrast: 1.1997 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 5/50
# 472/472 [==============================] - 226s 479ms/step - loss: 0.6315 - recon: 0.7890 - kl: 0.0444 - contrast: 1.1997 - beta: 0.2249 - gamma: 0.0000e+00 - sim_kl_recon: -0.3756 - sim_con_recon: 0.3741 - sim_con_kl: 0.0188 - val_total: 2.9797 - val_recon: 0.7614 - val_kl: 0.0290 - val_contrast: 1.2007 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 6/50
# 472/472 [==============================] - 226s 479ms/step - loss: 0.5666 - recon: 0.7249 - kl: 0.0266 - contrast: 1.2091 - beta: 0.2500 - gamma: 0.0000e+00 - sim_kl_recon: -0.2711 - sim_con_recon: 0.4084 - sim_con_kl: 0.0410 - val_total: 2.9517 - val_recon: 0.7079 - val_kl: 0.0236 - val_contrast: 1.2074 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 7/50
# 472/472 [==============================] - 226s 478ms/step - loss: 0.5410 - recon: 0.6813 - kl: 0.0225 - contrast: 1.2178 - beta: 0.2500 - gamma: 0.0000e+00 - sim_kl_recon: -0.1742 - sim_con_recon: 0.3467 - sim_con_kl: -0.2299 - val_total: 2.9385 - val_recon: 0.6723 - val_kl: 0.0211 - val_contrast: 1.2145 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 8/50
# 472/472 [==============================] - 226s 478ms/step - loss: 0.4962 - recon: 0.6445 - kl: 0.0203 - contrast: 1.2235 - beta: 0.2500 - gamma: 0.0000e+00 - sim_kl_recon: -0.1399 - sim_con_recon: 0.2972 - sim_con_kl: -0.4005 - val_total: 2.9329 - val_recon: 0.6396 - val_kl: 0.0198 - val_contrast: 1.2241 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 9/50
# 472/472 [==============================] - 226s 478ms/step - loss: 0.4942 - recon: 0.6105 - kl: 0.0182 - contrast: 1.2293 - beta: 0.2500 - gamma: 0.0000e+00 - sim_kl_recon: -0.1477 - sim_con_recon: 0.2138 - sim_con_kl: -0.4629 - val_total: 2.9256 - val_recon: 0.6036 - val_kl: 0.0167 - val_contrast: 1.2344 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 10/50
# 472/472 [==============================] - 226s 478ms/step - loss: 0.4462 - recon: 0.5802 - kl: 0.0161 - contrast: 1.2344 - beta: 0.2500 - gamma: 0.0000e+00 - sim_kl_recon: -0.1163 - sim_con_recon: 0.2111 - sim_con_kl: -0.3746 - val_total: 2.9047 - val_recon: 0.5710 - val_kl: 0.0144 - val_contrast: 1.2364 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 11/50
# 472/472 [==============================] - 226s 478ms/step - loss: 0.5710 - recon: 0.5336 - kl: 0.3987 - contrast: 1.2051 - beta: 0.0249 - gamma: 0.0998 - sim_kl_recon: -0.1285 - sim_con_recon: 0.2674 - sim_con_kl: 0.1487 - val_total: 2.7952 - val_recon: 0.5345 - val_kl: 0.1646 - val_contrast: 1.1766 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 12/50
# 472/472 [==============================] - 226s 478ms/step - loss: 0.8018 - recon: 0.5211 - kl: 0.1173 - contrast: 1.1611 - beta: 0.0749 - gamma: 0.2998 - sim_kl_recon: -0.1280 - sim_con_recon: 0.4331 - sim_con_kl: -0.0772 - val_total: 2.7005 - val_recon: 0.5185 - val_kl: 0.0836 - val_contrast: 1.1453 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 13/50
# 472/472 [==============================] - 226s 478ms/step - loss: 0.9521 - recon: 0.5112 - kl: 0.0667 - contrast: 1.1208 - beta: 0.1249 - gamma: 0.4998 - sim_kl_recon: -0.1674 - sim_con_recon: 0.8589 - sim_con_kl: -0.1659 - val_total: 2.6054 - val_recon: 0.5131 - val_kl: 0.0522 - val_contrast: 1.1038 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 14/50
# 472/472 [==============================] - 225s 478ms/step - loss: 1.1591 - recon: 0.5060 - kl: 0.0432 - contrast: 1.0867 - beta: 0.1749 - gamma: 0.6998 - sim_kl_recon: -0.1909 - sim_con_recon: 0.8410 - sim_con_kl: -0.0806 - val_total: 2.5350 - val_recon: 0.5043 - val_kl: 0.0377 - val_contrast: 1.0736 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 15/50
# 472/472 [==============================] - 225s 477ms/step - loss: 1.3138 - recon: 0.5007 - kl: 0.0299 - contrast: 1.0591 - beta: 0.2249 - gamma: 0.8998 - sim_kl_recon: -0.2643 - sim_con_recon: 0.7782 - sim_con_kl: -0.0333 - val_total: 2.4860 - val_recon: 0.5145 - val_kl: 0.0263 - val_contrast: 1.0468 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 16/50
# 472/472 [==============================] - 225s 477ms/step - loss: 1.4762 - recon: 0.4970 - kl: 0.0245 - contrast: 1.0381 - beta: 0.2500 - gamma: 1.0998 - sim_kl_recon: -0.2669 - sim_con_recon: 0.6052 - sim_con_kl: -0.0440 - val_total: 2.4273 - val_recon: 0.4861 - val_kl: 0.0247 - val_contrast: 1.0283 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 17/50
# 472/472 [==============================] - 225s 478ms/step - loss: 1.6242 - recon: 0.4903 - kl: 0.0239 - contrast: 1.0209 - beta: 0.2500 - gamma: 1.2998 - sim_kl_recon: -0.2919 - sim_con_recon: 0.5448 - sim_con_kl: -0.0570 - val_total: 2.4191 - val_recon: 0.5022 - val_kl: 0.0234 - val_contrast: 1.0183 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 18/50
# 472/472 [==============================] - 226s 478ms/step - loss: 1.8176 - recon: 0.4861 - kl: 0.0239 - contrast: 1.0048 - beta: 0.2500 - gamma: 1.4998 - sim_kl_recon: -0.2978 - sim_con_recon: 0.5231 - sim_con_kl: -0.1038 - val_total: 2.3667 - val_recon: 0.4878 - val_kl: 0.0263 - val_contrast: 0.9972 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 19/50
# 472/472 [==============================] - 226s 478ms/step - loss: 2.0097 - recon: 0.4824 - kl: 0.0242 - contrast: 0.9906 - beta: 0.2500 - gamma: 1.6998 - sim_kl_recon: -0.3035 - sim_con_recon: 0.4968 - sim_con_kl: -0.1194 - val_total: 2.3392 - val_recon: 0.4839 - val_kl: 0.0229 - val_contrast: 0.9853 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 20/50
# 472/472 [==============================] - 226s 478ms/step - loss: 2.1963 - recon: 0.4823 - kl: 0.0247 - contrast: 0.9769 - beta: 0.2500 - gamma: 1.8998 - sim_kl_recon: -0.2890 - sim_con_recon: 0.5227 - sim_con_kl: -0.1159 - val_total: 2.3057 - val_recon: 0.4799 - val_kl: 0.0281 - val_contrast: 0.9694 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 21/50
# 472/472 [==============================] - 225s 478ms/step - loss: 2.3960 - recon: 0.4539 - kl: 0.4474 - contrast: 0.9651 - beta: 0.0249 - gamma: 2.0000 - sim_kl_recon: -0.0238 - sim_con_recon: 0.5223 - sim_con_kl: -0.2538 - val_total: 2.3070 - val_recon: 0.4489 - val_kl: 0.2036 - val_contrast: 0.9597 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 22/50
# 472/472 [==============================] - 225s 478ms/step - loss: 2.3599 - recon: 0.4577 - kl: 0.1429 - contrast: 0.9547 - beta: 0.0749 - gamma: 2.0000 - sim_kl_recon: -0.1543 - sim_con_recon: 0.5673 - sim_con_kl: -0.2139 - val_total: 2.2631 - val_recon: 0.4591 - val_kl: 0.1026 - val_contrast: 0.9465 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 23/50
# 472/472 [==============================] - 225s 478ms/step - loss: 2.2822 - recon: 0.4615 - kl: 0.0780 - contrast: 0.9401 - beta: 0.1249 - gamma: 2.0000 - sim_kl_recon: -0.2431 - sim_con_recon: 0.5007 - sim_con_kl: -0.1931 - val_total: 2.2248 - val_recon: 0.4574 - val_kl: 0.0604 - val_contrast: 0.9333 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 24/50
# 472/472 [==============================] - 225s 477ms/step - loss: 2.2440 - recon: 0.4613 - kl: 0.0483 - contrast: 0.9283 - beta: 0.1749 - gamma: 2.0000 - sim_kl_recon: -0.2968 - sim_con_recon: 0.5718 - sim_con_kl: -0.1664 - val_total: 2.1936 - val_recon: 0.4520 - val_kl: 0.0379 - val_contrast: 0.9225 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 25/50
# 472/472 [==============================] - 225s 478ms/step - loss: 2.2314 - recon: 0.4579 - kl: 0.0329 - contrast: 0.9187 - beta: 0.2249 - gamma: 2.0000 - sim_kl_recon: -0.3668 - sim_con_recon: 0.5456 - sim_con_kl: -0.1534 - val_total: 2.1841 - val_recon: 0.4583 - val_kl: 0.0323 - val_contrast: 0.9161 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 26/50
# 472/472 [==============================] - 226s 478ms/step - loss: 2.1638 - recon: 0.4551 - kl: 0.0266 - contrast: 0.9093 - beta: 0.2500 - gamma: 2.0000 - sim_kl_recon: -0.3717 - sim_con_recon: 0.5685 - sim_con_kl: -0.1372 - val_total: 2.1559 - val_recon: 0.4470 - val_kl: 0.0239 - val_contrast: 0.9074 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 27/50
# 472/472 [==============================] - 225s 478ms/step - loss: 2.1546 - recon: 0.4475 - kl: 0.0255 - contrast: 0.9036 - beta: 0.2500 - gamma: 2.0000 - sim_kl_recon: -0.4122 - sim_con_recon: 0.4897 - sim_con_kl: -0.1347 - val_total: 2.1396 - val_recon: 0.4422 - val_kl: 0.0222 - val_contrast: 0.9012 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 28/50
# 472/472 [==============================] - 226s 478ms/step - loss: 2.1559 - recon: 0.4414 - kl: 0.0246 - contrast: 0.8989 - beta: 0.2500 - gamma: 2.0000 - sim_kl_recon: -0.4226 - sim_con_recon: 0.5359 - sim_con_kl: -0.1274 - val_total: 2.1300 - val_recon: 0.4366 - val_kl: 0.0247 - val_contrast: 0.8982 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 29/50
# 472/472 [==============================] - 225s 477ms/step - loss: 2.1112 - recon: 0.4350 - kl: 0.0241 - contrast: 0.8944 - beta: 0.2500 - gamma: 2.0000 - sim_kl_recon: -0.4504 - sim_con_recon: 0.4980 - sim_con_kl: -0.1234 - val_total: 2.1075 - val_recon: 0.4268 - val_kl: 0.0243 - val_contrast: 0.8907 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 30/50
# 472/472 [==============================] - 225s 477ms/step - loss: 2.1081 - recon: 0.4299 - kl: 0.0235 - contrast: 0.8908 - beta: 0.2500 - gamma: 2.0000 - sim_kl_recon: -0.4471 - sim_con_recon: 0.4127 - sim_con_kl: -0.1182 - val_total: 2.0990 - val_recon: 0.4236 - val_kl: 0.0228 - val_contrast: 0.8878 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 31/50
# 472/472 [==============================] - 225s 478ms/step - loss: 2.1743 - recon: 0.3997 - kl: 0.4298 - contrast: 0.8878 - beta: 0.0249 - gamma: 2.0000 - sim_kl_recon: -0.0825 - sim_con_recon: 0.4008 - sim_con_kl: -0.1458 - val_total: 2.1166 - val_recon: 0.3983 - val_kl: 0.1831 - val_contrast: 0.8860 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 32/50
# 472/472 [==============================] - 226s 478ms/step - loss: 2.1565 - recon: 0.4006 - kl: 0.1276 - contrast: 0.8867 - beta: 0.0749 - gamma: 2.0000 - sim_kl_recon: -0.2926 - sim_con_recon: 0.4578 - sim_con_kl: -0.1490 - val_total: 2.0958 - val_recon: 0.4055 - val_kl: 0.0883 - val_contrast: 0.8848 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 33/50
# 472/472 [==============================] - 225s 477ms/step - loss: 2.1473 - recon: 0.4020 - kl: 0.0674 - contrast: 0.8850 - beta: 0.1249 - gamma: 2.0000 - sim_kl_recon: -0.4013 - sim_con_recon: 0.4542 - sim_con_kl: -0.1390 - val_total: 2.0745 - val_recon: 0.3939 - val_kl: 0.0541 - val_contrast: 0.8828 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 34/50
# 472/472 [==============================] - 225s 478ms/step - loss: 2.1069 - recon: 0.4006 - kl: 0.0427 - contrast: 0.8822 - beta: 0.1749 - gamma: 2.0000 - sim_kl_recon: -0.5007 - sim_con_recon: 0.4167 - sim_con_kl: -0.1385 - val_total: 2.0644 - val_recon: 0.3947 - val_kl: 0.0376 - val_contrast: 0.8795 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 35/50
# 472/472 [==============================] - 225s 477ms/step - loss: 2.0760 - recon: 0.4014 - kl: 0.0293 - contrast: 0.8804 - beta: 0.2249 - gamma: 2.0000 - sim_kl_recon: -0.5378 - sim_con_recon: 0.4224 - sim_con_kl: -0.1255 - val_total: 2.0620 - val_recon: 0.3973 - val_kl: 0.0228 - val_contrast: 0.8792 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 36/50
# 472/472 [==============================] - 227s 480ms/step - loss: 2.0554 - recon: 0.3982 - kl: 0.0239 - contrast: 0.8778 - beta: 0.2500 - gamma: 2.0000 - sim_kl_recon: -0.6103 - sim_con_recon: 0.3251 - sim_con_kl: -0.1187 - val_total: 2.0514 - val_recon: 0.3890 - val_kl: 0.0209 - val_contrast: 0.8772 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 37/50
# 472/472 [==============================] - 226s 478ms/step - loss: 2.0501 - recon: 0.3951 - kl: 0.0234 - contrast: 0.8767 - beta: 0.2500 - gamma: 2.0000 - sim_kl_recon: -0.5972 - sim_con_recon: 0.3562 - sim_con_kl: -0.1211 - val_total: 2.0445 - val_recon: 0.3873 - val_kl: 0.0264 - val_contrast: 0.8737 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 38/50
# 472/472 [==============================] - 225s 477ms/step - loss: 2.0534 - recon: 0.3914 - kl: 0.0230 - contrast: 0.8751 - beta: 0.2500 - gamma: 2.0000 - sim_kl_recon: -0.6293 - sim_con_recon: 0.3413 - sim_con_kl: -0.1141 - val_total: 2.0419 - val_recon: 0.3830 - val_kl: 0.0230 - val_contrast: 0.8745 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 39/50
# 472/472 [==============================] - 226s 478ms/step - loss: 2.0335 - recon: 0.3888 - kl: 0.0226 - contrast: 0.8731 - beta: 0.2500 - gamma: 2.0000 - sim_kl_recon: -0.6504 - sim_con_recon: 0.2970 - sim_con_kl: -0.1184 - val_total: 2.0328 - val_recon: 0.3785 - val_kl: 0.0226 - val_contrast: 0.8716 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 40/50
# 472/472 [==============================] - 225s 478ms/step - loss: 2.0394 - recon: 0.3862 - kl: 0.0223 - contrast: 0.8721 - beta: 0.2500 - gamma: 2.0000 - sim_kl_recon: -0.6534 - sim_con_recon: 0.3312 - sim_con_kl: -0.1105 - val_total: 2.0338 - val_recon: 0.3797 - val_kl: 0.0248 - val_contrast: 0.8714 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 41/50
# 472/472 [==============================] - 225s 478ms/step - loss: 2.1075 - recon: 0.3622 - kl: 0.3687 - contrast: 0.8704 - beta: 0.0249 - gamma: 2.0000 - sim_kl_recon: -0.1325 - sim_con_recon: 0.2528 - sim_con_kl: -0.1256 - val_total: 2.0492 - val_recon: 0.3573 - val_kl: 0.1735 - val_contrast: 0.8689 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 42/50
# 472/472 [==============================] - 226s 478ms/step - loss: 2.0828 - recon: 0.3656 - kl: 0.1179 - contrast: 0.8701 - beta: 0.0749 - gamma: 2.0000 - sim_kl_recon: -0.4138 - sim_con_recon: 0.2784 - sim_con_kl: -0.1290 - val_total: 2.0352 - val_recon: 0.3613 - val_kl: 0.0834 - val_contrast: 0.8717 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 43/50
# 472/472 [==============================] - 226s 478ms/step - loss: 2.0613 - recon: 0.3684 - kl: 0.0633 - contrast: 0.8697 - beta: 0.1249 - gamma: 2.0000 - sim_kl_recon: -0.5624 - sim_con_recon: 0.2439 - sim_con_kl: -0.1236 - val_total: 2.0237 - val_recon: 0.3624 - val_kl: 0.0503 - val_contrast: 0.8697 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 44/50
# 472/472 [==============================] - 226s 478ms/step - loss: 2.0398 - recon: 0.3695 - kl: 0.0402 - contrast: 0.8690 - beta: 0.1749 - gamma: 2.0000 - sim_kl_recon: -0.6961 - sim_con_recon: 0.2088 - sim_con_kl: -0.1296 - val_total: 2.0191 - val_recon: 0.3652 - val_kl: 0.0324 - val_contrast: 0.8686 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 45/50
# 472/472 [==============================] - 225s 477ms/step - loss: 2.0296 - recon: 0.3708 - kl: 0.0280 - contrast: 0.8683 - beta: 0.2249 - gamma: 2.0000 - sim_kl_recon: -0.7606 - sim_con_recon: 0.2091 - sim_con_kl: -0.1258 - val_total: 2.0118 - val_recon: 0.3639 - val_kl: 0.0238 - val_contrast: 0.8665 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 46/50
# 472/472 [==============================] - 225s 477ms/step - loss: 2.0231 - recon: 0.3711 - kl: 0.0234 - contrast: 0.8668 - beta: 0.2500 - gamma: 2.0000 - sim_kl_recon: -0.7911 - sim_con_recon: 0.2295 - sim_con_kl: -0.1228 - val_total: 2.0120 - val_recon: 0.3625 - val_kl: 0.0236 - val_contrast: 0.8671 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 47/50
# 472/472 [==============================] - 225s 477ms/step - loss: 2.0117 - recon: 0.3700 - kl: 0.0228 - contrast: 0.8673 - beta: 0.2500 - gamma: 2.0000 - sim_kl_recon: -0.8103 - sim_con_recon: 0.2221 - sim_con_kl: -0.1184 - val_total: 2.0111 - val_recon: 0.3641 - val_kl: 0.0215 - val_contrast: 0.8663 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 48/50
# 472/472 [==============================] - 226s 478ms/step - loss: 2.0100 - recon: 0.3688 - kl: 0.0226 - contrast: 0.8667 - beta: 0.2500 - gamma: 2.0000 - sim_kl_recon: -0.8182 - sim_con_recon: 0.1373 - sim_con_kl: -0.1180 - val_total: 2.0075 - val_recon: 0.3629 - val_kl: 0.0230 - val_contrast: 0.8648 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 49/50
# 472/472 [==============================] - 225s 477ms/step - loss: 2.0150 - recon: 0.3678 - kl: 0.0224 - contrast: 0.8651 - beta: 0.2500 - gamma: 2.0000 - sim_kl_recon: -0.8350 - sim_con_recon: 0.1514 - sim_con_kl: -0.1141 - val_total: 2.0047 - val_recon: 0.3610 - val_kl: 0.0213 - val_contrast: 0.8643 - val_beta: 0.2500 - val_gamma: 2.0000
# Epoch 50/50
# 472/472 [==============================] - 225s 477ms/step - loss: 2.0082 - recon: 0.3668 - kl: 0.0222 - contrast: 0.8660 - beta: 0.2500 - gamma: 2.0000 - sim_kl_recon: -0.8430 - sim_con_recon: 0.1315 - sim_con_kl: -0.1191 - val_total: 2.0055 - val_recon: 0.3623 - val_kl: 0.0227 - val_contrast: 0.8641 - val_beta: 0.2500 - val_gamma: 2.0000
#
# Saving model...
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /global/common/software/nersc9/tensorflow/2.15.0/lib/python3.9/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
vae.summary()
# Out:
# Model: "vae_contrastive"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder (Functional)        [(None, 8),               1585168
#                               (None, 8),
#                               (None, 8)]
#
#  decoder (Functional)        (None, 57)                1624579
#
# =================================================================
# Total params: 3209760 (12.24 MB)
# Trainable params: 3209747 (12.24 MB)
# Non-trainable params: 13 (52.00 Byte)
# _________________________________________________________________

# %%
# Plot training history
plt.figure(figsize=(15, 10))

plt.subplot(3, 3, 1)
plt.plot(history.history['loss'], label='Total Loss')
# plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Total Loss')
plt.legend()

plt.subplot(3, 3, 2)
plt.plot(history.history['recon'], label='Recon Loss')
plt.plot(history.history['val_recon'], label='Val Recon Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Reconstruction Loss')
plt.legend()

plt.subplot(3, 3, 3)
plt.plot(history.history['kl'], label='KL Loss (unscaled)')
plt.plot(history.history['val_kl'], label='Val KL Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('KL Divergence Loss')
plt.legend()

plt.subplot(3, 3, 4)
plt.plot(history.history['contrast'], label='Contrastive Loss (unscaled)')
plt.plot(history.history['val_contrast'], label='Val Contrastive Loss (unscaled)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Contrastive Loss')
plt.legend()

plt.subplot(3, 3, 5)
plt.plot(history.history['sim_con_recon'], label='Contrastive Loss fight with Reconstruction')
plt.xlabel('Epoch')
plt.ylabel('Value')
plt.title('Contrastive Loss fight with Reconstruction')
plt.legend()

plt.subplot(3, 3, 6)
plt.plot(history.history['sim_con_kl'], label='Contrastive Loss fight with KL')
plt.xlabel('Epoch')
plt.ylabel('Value')
plt.title('Contrastive Loss fight with KL')
plt.legend()

plt.subplot(3, 3, 7)
plt.plot(history.history['beta'], label='KL weight')
plt.xlabel('Epoch')
plt.ylabel('Value')
plt.title('KL weight')
plt.legend()

plt.subplot(3, 3, 8)
plt.plot(history.history['gamma'], label='Contrastive loss weight')
plt.xlabel('Epoch')
plt.ylabel('Value')
plt.title('Contrastive loss weight')
plt.legend()

plt.tight_layout()
plt.savefig('../plots/training_history_10epochs_euclid_free.png')
plt.show()

# %%
# Get latent representations for all data
print("\nGenerating latent representations...")

def get_latent_mean(encoder, data, batch_size=1000):
    z_means = []
    for i in range(0, len(data), batch_size):
        batch = data[i:i+batch_size]
        z_mean = encoder.predict(batch, verbose=0)[0]   # [0] = μ
        z_means.append(z_mean)
    return np.concatenate(z_means, axis=0)

# Get latent representations
z_background = get_latent_mean(vae.encoder, X_test_scaled[:5000])
z_hToTauTau = get_latent_mean(vae.encoder, hToTauTau_data_scaled[:5000])
z_hChToTauNu = get_latent_mean(vae.encoder, hChToTauNu_data_scaled[:5000])
z_leptoquark = get_latent_mean(vae.encoder, leptoquark_data_scaled[:5000])
z_Ato4l = get_latent_mean(vae.encoder, Ato4l_data_scaled[:5000])

# Plot latent dimension distributions
print("\nPlotting latent dimension distributions...")
n_dims_to_plot = latent_dim
fig, axes = plt.subplots(2, 4, figsize=(20, 10))
axes = axes.flatten()

for dim in range(n_dims_to_plot):
    ax = axes[dim]
    
    # Plot histograms for each signal type
    ax.hist(z_background[:, dim], bins=30, alpha=0.5, label='Background', density=True)    
    ax.hist(z_hToTauTau[:, dim], bins=30, alpha=0.5, label='hToTauTau', density=True)
    ax.hist(z_hChToTauNu[:, dim], bins=30, alpha=0.5, label='hChToTauNu', density=True)
    ax.hist(z_leptoquark[:, dim], bins=30, alpha=0.5, label='Leptoquark', density=True)
    ax.hist(z_Ato4l[:, dim], bins=30, alpha=0.5, label='Ato4l', density=True)
    
    # ax.set_xlim(-5, 5)
    ax.set_title(f'Latent Dimension {dim + 1}')
    ax.set_xlabel('z_mean value')
    ax.set_ylabel('Density')
    ax.legend()

plt.tight_layout()
plt.savefig('../plots/latent_distributions_10epochs_euclid_free.png')
plt.show()
# Out:
# Generating latent representations...
#
# Plotting latent dimension distributions...

# %%
# t-SNE visualization
print("\nGenerating t-SNE visualization...")

# Combine all data for t-SNE
all_z = np.concatenate([z_background, z_hToTauTau, z_hChToTauNu, z_leptoquark, z_Ato4l])
labels = np.concatenate([
    np.zeros(len(z_background)),
    np.ones(len(z_hToTauTau)) * 1,
    np.ones(len(z_hChToTauNu)) * 2,
    np.ones(len(z_leptoquark)) * 3,
    np.ones(len(z_Ato4l)) * 4
])

# Perform t-SNE
tsne = TSNE(n_components=2, random_state=42, perplexity=30)
z_tsne = tsne.fit_transform(all_z)

# # Plot t-SNE
# plt.figure(figsize=(12, 10))
# scatter = plt.scatter(z_tsne[:, 0], z_tsne[:, 1], c=labels, cmap='tab10', alpha=0.6, s=10)

# # Add legend
legend_labels = ['Background', 'hToTauTau', 'hChToTauNu', 'Leptoquark', 'Ato4l']
legend_elements = [plt.Line2D([0], [0], marker='o', color='w', 
                             markerfacecolor=plt.cm.tab10(i/10), markersize=10, 
                             label=legend_labels[i]) for i in range(5)]
# plt.legend(handles=legend_elements, loc='best')

# plt.title('t-SNE Visualization of Latent Space')
# plt.xlabel('t-SNE 1')
# plt.ylabel('t-SNE 2')
# plt.savefig('../plots/tsne_latent_space_10epochs.png')
# plt.show()

# Create a more detailed t-SNE plot with contours
plt.figure(figsize=(12, 10))

# Plot each class separately with different markers
markers = ['o', 's', '^', 'D', 'v']
colors = ['blue', 'red', 'green', 'orange', 'purple']

for i, (label, marker, color) in enumerate(zip(legend_labels, markers, colors)):
    mask = labels == i
    plt.scatter(z_tsne[mask, 0], z_tsne[mask, 1], 
               c=color, marker=marker, alpha=0.3, s=30, label=label)

plt.legend()
plt.title('t-SNE Visualization of Latent Space (Detailed)')
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.grid(True, alpha=0.3)
plt.savefig('../plots/tsne_latent_space_detailed_10epochs_transformer.png')
plt.show()

print("\nTraining completed! Plots saved to ../plots/")
# Out:
# Generating t-SNE visualization...
# Training completed! Plots saved to ../plots/

# %%
# import umap.umap_ as umap

# # --- UMAP instead of t-SNE ---
# print("\nGenerating UMAP visualization...")

# reducer = umap.UMAP(
#     n_neighbors=30,      # similar role to perplexity
#     min_dist=0.1,        # controls clustering tightness
#     metric="euclidean",
#     random_state=42
# )
# z_umap = reducer.fit_transform(all_z)

# plt.figure(figsize=(12, 10))

# # Plot each class separately with different markers
# markers = ['o', 's', '^', 'D', 'v']
# colors = ['blue', 'red', 'green', 'orange', 'purple']

# for i, (label, marker, color) in enumerate(zip(legend_labels, markers, colors)):
#     mask = labels == i
#     plt.scatter(z_umap[mask, 0], z_umap[mask, 1], 
#                c=color, marker=marker, alpha=0.6, s=30, label=label)

# plt.legend()
# plt.title('UMAP Visualization of Latent Space')
# plt.xlabel('UMAP 1')
# plt.ylabel('UMAP 2')
# plt.grid(True, alpha=0.3)
# plt.savefig('../plots/umap_latent_space_detailed_10epochs_free.png')
# plt.show()

# %%
# ------------------------------------------------------------------
# helper: latent anomaly score  =  mean(z_mean**2) per event
# ------------------------------------------------------------------
def anomaly_scores(encoder, data, batch_size=4096):
    """
    Returns a 1-D array of anomaly scores for `data`.
    Score = average of squared latent means.
    """
    scores = np.empty(len(data), dtype=np.float32)
    for i in trange(0, len(data), batch_size, desc="scoring", leave=False):
        z_mean = encoder.predict(data[i:i+batch_size], verbose=0)[0]  # (z_mean, z_logv, z)
        scores[i:i+batch_size] = np.mean(np.square(z_mean), axis=1)
    return scores


# ------------------------------------------------------------------
# 1. compute scores
# ------------------------------------------------------------------
bg_scores        = anomaly_scores(vae.encoder, X_test_scaled)            # background
ato4l_scores     = anomaly_scores(vae.encoder, Ato4l_data_scaled)
hTauTau_scores   = anomaly_scores(vae.encoder, hToTauTau_data_scaled)
hChTauNu_scores  = anomaly_scores(vae.encoder, hChToTauNu_data_scaled)
lq_scores        = anomaly_scores(vae.encoder, leptoquark_data_scaled)

# %%
# ------------------------------------------------------------------
# 2. build ROC curves
# ------------------------------------------------------------------
signals = {
    "Ato4l"       : ato4l_scores,
    "h→ττ"        : hTauTau_scores,
    "H±→τν"       : hChTauNu_scores,
    "Leptoquark"  : lq_scores,
}

target_fpr = 1e-5
eff_at_target = {}

plt.figure(figsize=(6,6))
for name, s_scores in signals.items():
    y_true = np.concatenate([np.zeros_like(bg_scores), np.ones_like(s_scores)])
    y_pred = np.concatenate([bg_scores, s_scores])

    fpr, tpr, _ = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)
    
    # interpolate efficiency at target FPR
    eff = np.interp(target_fpr, fpr, tpr)
    eff_at_target[name] = eff
    
    plt.plot(fpr, tpr, label=f"{name} (AUC={roc_auc:.3f}, eff@1e-5={eff:.3g})")

# chance line
plt.plot([1e-6,1], [1e-6,1], "--", color="grey", lw=1)
plt.xscale("log")
plt.yscale("log")
plt.xlim(1e-6, 1)
plt.ylim(1e-6, 1)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate (Signal efficiency)")
plt.title("ROC curves (log‑log) for latent anomaly score")
plt.legend()
plt.grid(alpha=0.3, which="both")
plt.tight_layout()
plt.savefig("../plots/roc_latent_anomaly_loglog_free.png")
plt.show()

# print efficiencies
for n, e in eff_at_target.items():
    print(f"{n:12s} efficiency @ FPR=1e-5 : {e*100:.3g} %")

# %%
# after fitting
tsne3 = TSNE(n_components=3, random_state=42, perplexity=30)
z_tsne3 = tsne3.fit_transform(all_z)

# save to disk
joblib.dump(tsne3, 'tsne3_model.joblib')
np.save('z_tsne3.npy', z_tsne3)

# later, load from disk
tsne3 = joblib.load('tsne3_model.joblib')
z_tsne3 = np.load('z_tsne3.npy')

# %%
import plotly.express as px
import pandas as pd

# perform 3D t-SNE
tsne3 = TSNE(n_components=3, random_state=42, perplexity=30)
z_tsne3 = tsne3.fit_transform(all_z)

# prepare DataFrame
df = pd.DataFrame({
    'TSNE1': z_tsne3[:, 0],
    'TSNE2': z_tsne3[:, 1],
    'TSNE3': z_tsne3[:, 2],
    'label': labels
})
df['label'] = df['label'].map({
    0: 'Background',
    1: 'hToTauTau',
    2: 'hChToTauNu',
    3: 'Leptoquark',
    4: 'Ato4l'
})

# interactive 3D scatter
fig = px.scatter_3d(
    df,
    x='TSNE1', y='TSNE2', z='TSNE3',
    color='label',
    title='3D t-SNE of Latent Space',
    opacity=0.7
)
fig.update_traces(marker=dict(size=4))
fig.write_html('../plots/tsne_latent_space_3d.html')

# %%
# ------------------------------------------------------------------
# V1: latent‐space anomaly score  = mean(z_mean**2) per event
# ------------------------------------------------------------------
def anomaly_scores_latent(encoder, data, batch_size=4096):
    """
    Returns a 1-D array of latent‐space anomaly scores.
    Score = average of squared z_mean per event.
    """
    scores = np.empty(len(data), dtype=np.float32)
    for i in trange(0, len(data), batch_size, desc="latent scoring", leave=False):
        z_mean, _, _ = encoder.predict(data[i:i+batch_size], verbose=0)
        scores[i:i+batch_size] = np.mean(np.square(z_mean), axis=1)
    return scores

# ------------------------------------------------------------------
# V2: reconstruction-based anomaly score using your masked_mse
# ------------------------------------------------------------------
def anomaly_scores_mse(vae, data, batch_size=4096):
    scores = np.empty(len(data), dtype=np.float32)
    for i in trange(0, len(data), batch_size, desc="MSE scoring", leave=False):
        x_batch = data[i:i+batch_size]
        raw_out = vae.predict(x_batch, verbose=0)
        # unpack the dict your call() returns:
        recon = raw_out["reconstruction"] if isinstance(raw_out, dict) else raw_out
        mse_batch = vae.masked_mse(
            tf.convert_to_tensor(x_batch, dtype=tf.float32),
            tf.convert_to_tensor(recon,    dtype=tf.float32)
        )
        scores[i:i+batch_size] = mse_batch.numpy()
    return scores

def anomaly_scores_mse_gpu(vae, data, batch_size=4096*4):
    # make sure GPU is visible
    print("GPUs:", tf.config.list_physical_devices('GPU'))

    # tf.data pipeline
    ds = (tf.data.Dataset.from_tensor_slices(data)
          .batch(batch_size)
          .prefetch(tf.data.AUTOTUNE))

    # compile the scoring loop
    @tf.function
    def score_dataset(dataset):
        def _step(x):
            μ, logv, recon = vae(x, training=False)    # returns tensors directly
            return vae.masked_mse(x, recon)
        # concatenate all batch-scores
        return tf.concat([_step(batch) for batch in dataset], axis=0)

    # run and return a NumPy array
    return score_dataset(ds).numpy()

# ------------------------------------------------------------------
# 1. compute scores for both versions
# ------------------------------------------------------------------
datasets = {
    "BG"          : X_test_scaled,
    "Ato4l"       : Ato4l_data_scaled,
    "h→ττ"        : hToTauTau_data_scaled,
    "H±→τν"       : hChToTauNu_data_scaled,
    "Leptoquark"  : leptoquark_data_scaled,
}

# latent_scores = {name: anomaly_scores_latent(vae.encoder, data)
#                  for name, data in datasets.items()}
mse_scores    = {name: anomaly_scores_mse(vae, data)
                 for name, data in datasets.items()}

# %%
# ------------------------------------------------------------------
# 2. build & plot ROC curves side-by-side
# ------------------------------------------------------------------
def plot_rocs(scores_dict, title):
    target_fpr = 1e-5
    eff_at_target = {}
    plt.figure(figsize=(6,6))
    for name, s in scores_dict.items():
        if name == "BG": continue
        y_true = np.concatenate([np.zeros_like(scores_dict["BG"]), np.ones_like(s)])
        y_pred = np.concatenate([scores_dict["BG"], s])
        fpr, tpr, _ = roc_curve(y_true, y_pred)
        roc_auc = auc(fpr, tpr)
        eff = np.interp(target_fpr, fpr, tpr)
        eff_at_target[name] = eff
        plt.plot(fpr, tpr, label=f"{name} (AUC={roc_auc:.3f}, eff@1e-5={eff:.3g})")
    plt.plot([1e-6,1], [1e-6,1], "--", color="grey", lw=1)
    plt.xscale("log"); plt.yscale("log")
    plt.xlim(1e-6,1); plt.ylim(1e-6,1.5)
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(title)
    plt.legend(); plt.grid(alpha=0.3, which="both"); plt.tight_layout()
    plt.show()
    for n,e in eff_at_target.items():
        print(f"{n:12s} @1e-5 FPR: {e*100:.3g}%")
    print()

# plot_rocs(latent_scores, "ROC (log-log) — latent anomaly score")
plot_rocs(mse_scores,    "ROC (log-log) — masked MSE anomaly score")
# Out:
# Ato4l        @1e-5 FPR: 100%
# h→ττ         @1e-5 FPR: 4.74%
# H±→τν        @1e-5 FPR: 0.539%
# Leptoquark   @1e-5 FPR: 0%

# %%
import plotly.graph_objects as go
from scipy.stats import gaussian_kde
from sklearn.manifold import TSNE

# Assuming z_tsne3 and labels are already calculated as in your example
# z_tsne3 shape: (N_samples, 3)

# Compute KDE
kde = gaussian_kde(z_tsne3.T)

# Create grid to evaluate KDE
xmin, ymin, zmin = z_tsne3.min(axis=0) - 1
xmax, ymax, zmax = z_tsne3.max(axis=0) + 1

x, y, z = np.mgrid[xmin:xmax:50j, ymin:ymax:50j, zmin:zmax:50j]
grid_coords = np.vstack([x.ravel(), y.ravel(), z.ravel()])
density = kde(grid_coords).reshape(x.shape)

# Plot using Plotly isosurface
fig = go.Figure(data=go.Isosurface(
    x=x.flatten(),
    y=y.flatten(),
    z=z.flatten(),
    value=density.flatten(),
    isomin=density.mean(),
    isomax=density.max(),
    surface_count=10,
    colorscale='Viridis',
    caps=dict(x_show=False, y_show=False, z_show=False)
))

fig.update_layout(title="3D KDE of t-SNE Latent Space", scene=dict(
    xaxis_title='TSNE1',
    yaxis_title='TSNE2',
    zaxis_title='TSNE3'))

fig.write_html('../plots/tsne_latent_space_3d_kde.html')

# %%
import plotly.figure_factory as ff

# Perform 2D t-SNE
tsne2 = TSNE(n_components=2, random_state=42, perplexity=30)
z_tsne2 = tsne2.fit_transform(all_z)

# Create DataFrame
df = pd.DataFrame({
    'TSNE1': z_tsne2[:, 0],
    'TSNE2': z_tsne2[:, 1],
    'label': labels
})

# Map labels for readability
df['label'] = df['label'].map({
    0: 'Background',
    1: 'hToTauTau',
    2: 'hChToTauNu',
    3: 'Leptoquark',
    4: 'Ato4l'
})

# Separate DataFrames by label
channels = df['label'].unique()
colors = ['Blues', 'Greens', 'Reds', 'Purples', 'Oranges']

fig = None
for channel, color in zip(channels, colors):
    subset = df[df['label'] == channel]
    fig_channel = ff.create_2d_density(
        x=subset['TSNE1'],
        y=subset['TSNE2'],
        colorscale=color,
        show_hist=False,
        show_contour=True
    )
    
    # Update the trace name for clarity
    for trace in fig_channel.data:
        trace.name = channel
        trace.showlegend = True

    if fig is None:
        fig = fig_channel
    else:
        fig.add_traces(fig_channel.data)

fig.update_layout(title='Overlayed 2D KDE of t-SNE Latent Space by Channel')
fig.write_html('../plots/tsne_latent_space_2d_kde.html')

# %%
print(vae.encoder.predict(X_test_scaled[:3])[1])
# Out:
# 1/1 [==============================] - 0s 255ms/step
# [[ 0.0204953  -0.07431126 -0.07142019 -0.03306448 -0.1065439   0.0674324
#   -0.0470134  -0.14080513]
#  [-0.01043653 -0.12630427 -0.08719957 -0.01870978 -0.11382008  0.08827782
#   -0.04007363 -0.12607431]
#  [-0.08762228 -0.0875144  -0.1001302   0.00193393 -0.15860915 -0.02392948
#   -0.06409097 -0.10867512]]
